# %% [markdown]
# | Data name| In master function |  All years dataframe
# | -------- | -------- |  -------- |
# |Schüler/-innen je Lehrkraft | teachers_yyyy| teachers_concat
# |Anzahl an Lehrkräften | students_per_teacher_yyyy| students_per_teacher_concat
# |Anzahl an Schülern | students_yyyy| students_concat
# |Unterichtsstd. Je Schüler	| hours_per_student_yyyy|hours_per_student_concat
# |Ausgaben 	| ausgaben_yyyy|ausgaben_concat

# %%
from test_ausgaben import ausgaben_concat, ausgaben_2010, ausgaben_2011, ausgaben_2012, ausgaben_2013, ausgaben_2014, ausgaben_2015, ausgaben_2016
# Out:
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/test_ausgaben.py:71: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ausgaben.iloc[:, 1:15] = ausgaben.iloc[:, 1:15].astype('Int64')

# %%
ausgaben_concat
# Out:
#         Federal States  Allg bildende Schulen  Berufliche Schulen Insgesamt  \
# 0    Baden-Württemberg                   6300                          4700
# 1               Bayern                   6900                          3800
# 2               Berlin                   7600                          4400
# 3          Brandenburg                   6700                          3600
# 4               Bremen                   7000                          3600
# ..                 ...                    ...                           ...
# 11            Saarland                   8600                          5300
# 12             Sachsen                   8500                          5900
# 13      Sachsen-Anhalt                   8200                          4900
# 14  Schleswig-Holstein                   8200                          5500
# 15           Thüringen                   9200                          7200
#
#     darunter: im Dualen System  Alle Schularten  Grund schulen  Hauptschulen  \
# 0                         2600             5900           5100          6500
# 1                         2700             6200           5700          8000
# 2                         2800             6900           6000             0
# 3                         3000             6000           4800             0
# 4                         2400             6000           5900             0
# ..                         ...              ...            ...           ...
# 11                        3600             7700           7200             0
# 12                        4000             8100           6700             0
# 13                        3200             7600           6200             0
# 14                        4200             7500           6600             0
# 15                        4500             8900           7100             0
#
#     Schulen mit mehreren Bildungsgängen  Realschulen  Gymnasien  \
# 0                                     0         5300       6700
# 1                                     0         6300       7500
# 2                                     0         7400       7400
# 3                                  8200            0       6800
# 4                                  6900            0       6400
# ..                                  ...          ...        ...
# 11                                    0            0       9100
# 12                                 8700            0       9100
# 13                                 9000            0       8500
# 14                                    0            0       8200
# 15                                10000            0      10100
#
#     Integrierte Gesamt schulen  Personalausgaben  Laufender Sach-aufwand  \
# 0                            0              4600                     700
# 1                            0              4500                     700
# 2                         8600              5600                    1000
# 3                         8000              4700                     700
# 4                         7200              4500                    1200
# ..                         ...               ...                     ...
# 11                        8400              6300                    1000
# 12                           0              6200                     900
# 13                        8100              6400                     800
# 14                        9000              6100                    1000
# 15                        9900              7400                     900
#
#     Investi-tionsaus-gaben  Gesamtausgaben darunter: von staatlicher Ebene  \
# 0                      600            5900                            4300
# 1                      900            6200                            4000
# 2                      300            6900                            6900
# 3                      700            6000                            4400
# 4                      300            6000                            6000
# ..                     ...             ...                             ...
# 11                     400            7700                            6200
# 12                     900            8100                            6000
# 13                     400            7600                            6200
# 14                     400            7500                            5700
# 15                     500            8900                            7100
#
#          year
# 0  2010-01-01
# 1  2010-01-01
# 2  2010-01-01
# 3  2010-01-01
# 4  2010-01-01
# ..        ...
# 11 2019-01-01
# 12 2019-01-01
# 13 2019-01-01
# 14 2019-01-01
# 15 2019-01-01
#
# [144 rows x 17 columns]
