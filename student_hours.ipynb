# %% [markdown]
# | Data name| In master function |  All years variable
# | -------- | -------- |  -------- |
# |Schüler/-innen je Lehrkraft | teachers| teachers_concat
# |Anzahl an Lehrkräften | students_per_teacher| students_per_teacher_concat
# |Anzahl an Schülern | students| students_concat
# |Unterichtsstd. Je Schüler	| hours_per_student|hours_per_student_concat

# %%
import pandas as pd
#pd.set_option('display.max_rows', None)

from master import hours_per_student_2011, hours_per_student_2012, hours_per_student_2013, hours_per_student_2014, hours_per_student_2015, hours_per_student_2016, hours_per_student_2017, hours_per_student_2018, hours_per_student_2019, hours_per_student_2020, hours_per_student_2021

# %%
hours_per_student_concat = pd.concat([  hours_per_student_2011, hours_per_student_2012, hours_per_student_2013,
                            hours_per_student_2014, hours_per_student_2015, hours_per_student_2016,
                            hours_per_student_2017, hours_per_student_2018, hours_per_student_2019,
                            hours_per_student_2020, hours_per_student_2021], ignore_index=True)

# %%
hours_per_student_concat.head()
# Out:
#                    SchoolType  Baden-Wüttemberg    Bayern    Berlin  \
# 0  Allgemein bildende Schulen          1.713945  1.585794  1.754554
# 1           Sekundarbereich I          1.573263  1.560799  1.795453
# 2          Sekundarbereich II          1.315289  1.137183  1.326992
# 3  Allgemein bildende Schulen          1.725627  1.603869  1.755236
# 4           Sekundarbereich I          1.579648  1.572521  1.808520
#
#    Brandenburg    Bremen   Hamburg    Hessen  Mecklenburg-Vorpommern  \
# 0     1.770079  1.714481  1.690766  1.648265                1.788607
# 1     1.787801  1.664775  1.611509  1.533235                1.830719
# 2     1.277223  1.114163  1.192419  1.171841                1.179430
# 3     1.763702  1.721590  1.720837  1.668937                1.785292
# 4     1.778945  1.700550  1.619456  1.509934                1.824199
#
#    Niedersachsen  Nordrhein-Westfalen  Rheinland-Pfalz  Saarland   Sachsen  \
# ...
