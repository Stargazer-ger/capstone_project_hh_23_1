# %% [markdown]
# # Dropouts of male / female and all students throut the years

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data
dropouts = pd.read_csv('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/graduation_by_gender_jw.csv', encoding='UTF-8', delimiter=';')

# %%
# First look at data
dropouts
# Out:
#                                             Unnamed: 0    Unnamed: 1  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                    Baden-Württemberg  Hauptschulen
# 4                                    Baden-Württemberg  Hauptschulen
# ..                                                 ...           ...
# 866                                          Thüringen     Insgesamt
# 867                                         __________           NaN
# 868  Ab 2012/13:\nMittlerer Schulabschluss einschli...           NaN
# 869         © Statistisches Bundesamt (Destatis), 2022           NaN
# 870                       Stand: 13.04.2023 / 12:47:51           NaN
#
#                     Abschluss   Schuljahr Schuljahr.1 Schuljahr.2 Schuljahr.3  \
# ...

# %%
# sort by 'ohne Haupschulabschluss' as dropouts_oh
dropouts_oh = dropouts[dropouts['Abschluss'] == 'Ohne Hauptschulabschluss']

# save df as csv
dropouts_oh.to_csv('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/graduation_by_gender_jw2.csv', index=False)

dropouts_oh
# Out:
#             Unnamed: 0                              Unnamed: 1  \
# 3    Baden-Württemberg                            Hauptschulen
# 9    Baden-Württemberg  Schularten mit mehreren Bildungsgängen
# 15   Baden-Württemberg                             Realschulen
# 21   Baden-Württemberg                          Gymnasien (G9)
# 27   Baden-Württemberg                          Gymnasien (G8)
# ..                 ...                                     ...
# 837          Thüringen                          Gymnasien (G8)
# 843          Thüringen               Integrierte Gesamtschulen
# 849          Thüringen                    Freie Waldorfschulen
# 855          Thüringen                           Förderschulen
# 861          Thüringen                               Insgesamt
#
#                     Abschluss Schuljahr Schuljahr.1 Schuljahr.2 Schuljahr.3  \
# 3    Ohne Hauptschulabschluss       784         491        1275         679
# ...

# %%
#create df for all federal states by iloc

# Read data
dropouts_filtered = pd.read_csv('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/graduation_by_gender_jw2.csv', encoding='UTF-8')

# %%
# Umbenennen des Headers
dropouts_filtered.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#             Bundesland                                  Schule  \
# 0    Baden-Württemberg                            Hauptschulen
# 1    Baden-Württemberg  Schularten mit mehreren Bildungsgängen
# 2    Baden-Württemberg                             Realschulen
# 3    Baden-Württemberg                          Gymnasien (G9)
# 4    Baden-Württemberg                          Gymnasien (G8)
# ..                 ...                                     ...
# 139          Thüringen                          Gymnasien (G8)
# 140          Thüringen               Integrierte Gesamtschulen
# 141          Thüringen                    Freie Waldorfschulen
# 142          Thüringen                           Förderschulen
# 143          Thüringen                               Insgesamt
#
#                     Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 0    Ohne Hauptschulabschluss   784   491  1275   679   443  1122   675  ...
# ...

# %%
# wieviel zeilen umfasst jedes Bundesland?
dropouts_filtered.head(10)
# Out:
#           Unnamed: 0                              Unnamed: 1  \
# 0  Baden-Württemberg                            Hauptschulen
# 1  Baden-Württemberg  Schularten mit mehreren Bildungsgängen
# 2  Baden-Württemberg                             Realschulen
# 3  Baden-Württemberg                          Gymnasien (G9)
# 4  Baden-Württemberg                          Gymnasien (G8)
# 5  Baden-Württemberg               Integrierte Gesamtschulen
# 6  Baden-Württemberg                    Freie Waldorfschulen
# 7  Baden-Württemberg                           Förderschulen
# 8  Baden-Württemberg                               Insgesamt
# 9             Bayern                            Hauptschulen
#
#                   Abschluss Schuljahr Schuljahr.1 Schuljahr.2 Schuljahr.3  \
# 0  Ohne Hauptschulabschluss       784         491        1275         679
# 1  Ohne Hauptschulabschluss         -           -           -           -
# ...

# %% [markdown]
# # iloc für jedes Bundesland

# %%
dropouts_bw = dropouts_filtered.iloc[0:9]

dropouts_bw.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#           Bundesland                                  Schule  \
# 0  Baden-Württemberg                            Hauptschulen
# 1  Baden-Württemberg  Schularten mit mehreren Bildungsgängen
# 2  Baden-Württemberg                             Realschulen
# 3  Baden-Württemberg                          Gymnasien (G9)
# 4  Baden-Württemberg                          Gymnasien (G8)
# 5  Baden-Württemberg               Integrierte Gesamtschulen
# 6  Baden-Württemberg                    Freie Waldorfschulen
# 7  Baden-Württemberg                           Förderschulen
# 8  Baden-Württemberg                               Insgesamt
#
#                   Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 0  Ohne Hauptschulabschluss   784   491  1275   679   443  1122   675  ...
# 1  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 2  Ohne Hauptschulabschluss   521   322   843   457   320   777   462  ...
# ...

# %%
dropouts_by = dropouts_filtered.iloc[9:18]

dropouts_by.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#    Bundesland                                  Schule  \
# 9      Bayern                            Hauptschulen
# 10     Bayern  Schularten mit mehreren Bildungsgängen
# 11     Bayern                             Realschulen
# 12     Bayern                          Gymnasien (G9)
# 13     Bayern                          Gymnasien (G8)
# 14     Bayern               Integrierte Gesamtschulen
# 15     Bayern                    Freie Waldorfschulen
# 16     Bayern                           Förderschulen
# 17     Bayern                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 9   Ohne Hauptschulabschluss  1776   930  2706  1463   826  2289  1519  ...
# 10  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 11  Ohne Hauptschulabschluss   256   175   431   307   190   497   304  ...
# 12  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_be = dropouts_filtered.iloc[18:27]

dropouts_be.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#    Bundesland                                  Schule  \
# 18     Berlin                            Hauptschulen
# 19     Berlin  Schularten mit mehreren Bildungsgängen
# 20     Berlin                             Realschulen
# 21     Berlin                          Gymnasien (G9)
# 22     Berlin                          Gymnasien (G8)
# 23     Berlin               Integrierte Gesamtschulen
# 24     Berlin                    Freie Waldorfschulen
# 25     Berlin                           Förderschulen
# 26     Berlin                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 18  Ohne Hauptschulabschluss   637   421  1058   574   356   930   418  ...
# 19  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 20  Ohne Hauptschulabschluss   149   100   249    88    67   155    98  ...
# 21  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_bb = dropouts_filtered.iloc[27:36]

dropouts_bb.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#      Bundesland                                  Schule  \
# 27  Brandenburg                            Hauptschulen
# 28  Brandenburg  Schularten mit mehreren Bildungsgängen
# 29  Brandenburg                             Realschulen
# 30  Brandenburg                          Gymnasien (G9)
# 31  Brandenburg                          Gymnasien (G8)
# 32  Brandenburg               Integrierte Gesamtschulen
# 33  Brandenburg                    Freie Waldorfschulen
# 34  Brandenburg                           Förderschulen
# 35  Brandenburg                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 27  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 28  Ohne Hauptschulabschluss   263   155   418   246   146   392   277  ...
# 29  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 30  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_hb = dropouts_filtered.iloc[36:45]

dropouts_hb.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#    Bundesland                                  Schule  \
# 36     Bremen                            Hauptschulen
# 37     Bremen  Schularten mit mehreren Bildungsgängen
# 38     Bremen                             Realschulen
# 39     Bremen                          Gymnasien (G9)
# 40     Bremen                          Gymnasien (G8)
# 41     Bremen               Integrierte Gesamtschulen
# 42     Bremen                    Freie Waldorfschulen
# 43     Bremen                           Förderschulen
# 44     Bremen                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 36  Ohne Hauptschulabschluss     -     -     -     -     1     1     -  ...
# 37  Ohne Hauptschulabschluss    50    24    74    36    23    59    24  ...
# 38  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 39  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_hh = dropouts_filtered.iloc[45:54]

dropouts_hh.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#    Bundesland                                  Schule  \
# 45    Hamburg                            Hauptschulen
# 46    Hamburg  Schularten mit mehreren Bildungsgängen
# 47    Hamburg                             Realschulen
# 48    Hamburg                          Gymnasien (G9)
# 49    Hamburg                          Gymnasien (G8)
# 50    Hamburg               Integrierte Gesamtschulen
# 51    Hamburg                    Freie Waldorfschulen
# 52    Hamburg                           Förderschulen
# 53    Hamburg                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 45  Ohne Hauptschulabschluss    99    59   158     -     -     -     -  ...
# 46  Ohne Hauptschulabschluss    55    32    87   134   102   236   125  ...
# 47  Ohne Hauptschulabschluss    14     8    22     2     3     5     -  ...
# 48  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_he = dropouts_filtered.iloc[54:63]

dropouts_he.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#    Bundesland                                  Schule  \
# 54     Hessen                            Hauptschulen
# 55     Hessen  Schularten mit mehreren Bildungsgängen
# 56     Hessen                             Realschulen
# 57     Hessen                          Gymnasien (G9)
# 58     Hessen                          Gymnasien (G8)
# 59     Hessen               Integrierte Gesamtschulen
# 60     Hessen                    Freie Waldorfschulen
# 61     Hessen                           Förderschulen
# 62     Hessen                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 54  Ohne Hauptschulabschluss   571   429  1000   460   372   832   479  ...
# 55  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 56  Ohne Hauptschulabschluss   111    64   175    92    68   160    88  ...
# 57  Ohne Hauptschulabschluss     2     4     6     1     2     3     2  ...
# ...

# %%
dropouts_mv = dropouts_filtered.iloc[63:72]

dropouts_mv.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#                 Bundesland                                  Schule  \
# 63  Mecklenburg-Vorpommern                            Hauptschulen
# 64  Mecklenburg-Vorpommern  Schularten mit mehreren Bildungsgängen
# 65  Mecklenburg-Vorpommern                             Realschulen
# 66  Mecklenburg-Vorpommern                          Gymnasien (G9)
# 67  Mecklenburg-Vorpommern                          Gymnasien (G8)
# 68  Mecklenburg-Vorpommern               Integrierte Gesamtschulen
# 69  Mecklenburg-Vorpommern                    Freie Waldorfschulen
# 70  Mecklenburg-Vorpommern                           Förderschulen
# 71  Mecklenburg-Vorpommern                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 63  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 64  Ohne Hauptschulabschluss   233   122   355   171   123   294   167  ...
# ...

# %%
dropouts_ni = dropouts_filtered.iloc[72:81]

dropouts_ni.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#        Bundesland                                  Schule  \
# 72  Niedersachsen                            Hauptschulen
# 73  Niedersachsen  Schularten mit mehreren Bildungsgängen
# 74  Niedersachsen                             Realschulen
# 75  Niedersachsen                          Gymnasien (G9)
# 76  Niedersachsen                          Gymnasien (G8)
# 77  Niedersachsen               Integrierte Gesamtschulen
# 78  Niedersachsen                    Freie Waldorfschulen
# 79  Niedersachsen                           Förderschulen
# 80  Niedersachsen                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 72  Ohne Hauptschulabschluss  1288   816  2104  1171   807  1978  1110  ...
# 73  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 74  Ohne Hauptschulabschluss    89    44   133    71    50   121    91  ...
# 75  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_nrw = dropouts_filtered.iloc[81:90]

dropouts_nrw.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#              Bundesland                                  Schule  \
# 81  Nordrhein-Westfalen                            Hauptschulen
# 82  Nordrhein-Westfalen  Schularten mit mehreren Bildungsgängen
# 83  Nordrhein-Westfalen                             Realschulen
# 84  Nordrhein-Westfalen                          Gymnasien (G9)
# 85  Nordrhein-Westfalen                          Gymnasien (G8)
# 86  Nordrhein-Westfalen               Integrierte Gesamtschulen
# 87  Nordrhein-Westfalen                    Freie Waldorfschulen
# 88  Nordrhein-Westfalen                           Förderschulen
# 89  Nordrhein-Westfalen                               Insgesamt
#
#                    Abschluss 2010m 2010w  2010g 2011m 2011w  2011g 2012m  ...  \
# 81  Ohne Hauptschulabschluss  2267  1442   3709  1955  1322   3277  1876  ...
# 82  Ohne Hauptschulabschluss     -     -      -     -     -      -     -  ...
# 83  Ohne Hauptschulabschluss   331   214    545   287   204    491   265  ...
# ...

# %%
dropouts_rp = dropouts_filtered.iloc[90:99]

dropouts_rp.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#          Bundesland                                  Schule  \
# 90  Rheinland-Pfalz                            Hauptschulen
# 91  Rheinland-Pfalz  Schularten mit mehreren Bildungsgängen
# 92  Rheinland-Pfalz                             Realschulen
# 93  Rheinland-Pfalz                          Gymnasien (G9)
# 94  Rheinland-Pfalz                          Gymnasien (G8)
# 95  Rheinland-Pfalz               Integrierte Gesamtschulen
# 96  Rheinland-Pfalz                    Freie Waldorfschulen
# 97  Rheinland-Pfalz                           Förderschulen
# 98  Rheinland-Pfalz                               Insgesamt
#
#                    Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 90  Ohne Hauptschulabschluss   289   199   488   119   101   220    58  ...
# 91  Ohne Hauptschulabschluss   265   145   410   410   228   638   442  ...
# 92  Ohne Hauptschulabschluss    56    28    84     7     5    12     5  ...
# ...

# %%
dropouts_saar = dropouts_filtered.iloc[99:108]

dropouts_saar.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#     Bundesland                                  Schule  \
# 99    Saarland                            Hauptschulen
# 100   Saarland  Schularten mit mehreren Bildungsgängen
# 101   Saarland                             Realschulen
# 102   Saarland                          Gymnasien (G9)
# 103   Saarland                          Gymnasien (G8)
# 104   Saarland               Integrierte Gesamtschulen
# 105   Saarland                    Freie Waldorfschulen
# 106   Saarland                           Förderschulen
# 107   Saarland                               Insgesamt
#
#                     Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 99   Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 100  Ohne Hauptschulabschluss    96    78   174    98    60   158    73  ...
# 101  Ohne Hauptschulabschluss     -     -     -     2     3     5     1  ...
# 102  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_sachsen = dropouts_filtered.iloc[108:117]

dropouts_sachsen.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#     Bundesland                                  Schule  \
# 108    Sachsen                            Hauptschulen
# 109    Sachsen  Schularten mit mehreren Bildungsgängen
# 110    Sachsen                             Realschulen
# 111    Sachsen                          Gymnasien (G9)
# 112    Sachsen                          Gymnasien (G8)
# 113    Sachsen               Integrierte Gesamtschulen
# 114    Sachsen                    Freie Waldorfschulen
# 115    Sachsen                           Förderschulen
# 116    Sachsen                               Insgesamt
#
#                     Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 108  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 109  Ohne Hauptschulabschluss   446   296   742   438   274   712   443  ...
# 110  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 111  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_sa_anh = dropouts_filtered.iloc[117:126]

dropouts_sa_anh.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#          Bundesland                                  Schule  \
# 117  Sachsen-Anhalt                            Hauptschulen
# 118  Sachsen-Anhalt  Schularten mit mehreren Bildungsgängen
# 119  Sachsen-Anhalt                             Realschulen
# 120  Sachsen-Anhalt                          Gymnasien (G9)
# 121  Sachsen-Anhalt                          Gymnasien (G8)
# 122  Sachsen-Anhalt               Integrierte Gesamtschulen
# 123  Sachsen-Anhalt                    Freie Waldorfschulen
# 124  Sachsen-Anhalt                           Förderschulen
# 125  Sachsen-Anhalt                               Insgesamt
#
#                     Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 117  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 118  Ohne Hauptschulabschluss   303   207   510   305   195   500   311  ...
# 119  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %%
dropouts_sh = dropouts_filtered.iloc[126:135]

dropouts_sh.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#              Bundesland                                  Schule  \
# 126  Schleswig-Holstein                            Hauptschulen
# 127  Schleswig-Holstein  Schularten mit mehreren Bildungsgängen
# 128  Schleswig-Holstein                             Realschulen
# 129  Schleswig-Holstein                          Gymnasien (G9)
# 130  Schleswig-Holstein                          Gymnasien (G8)
# 131  Schleswig-Holstein               Integrierte Gesamtschulen
# 132  Schleswig-Holstein                    Freie Waldorfschulen
# 133  Schleswig-Holstein                           Förderschulen
# 134  Schleswig-Holstein                               Insgesamt
#
#                     Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 126  Ohne Hauptschulabschluss   550   326   876   567   317   884   503  ...
# 127  Ohne Hauptschulabschluss     -     -     -     -     -     -    22  ...
# 128  Ohne Hauptschulabschluss    60    47   107    50    25    75    35  ...
# ...

# %%
dropouts_th = dropouts_filtered.iloc[135:144]

dropouts_th.rename(columns={'Unnamed: 0': 'Bundesland', 'Unnamed: 1': 'Schule',
                                'Schuljahr': '2010m', 'Schuljahr.1': '2010w', 'Schuljahr.2': '2010g',
                                'Schuljahr.3': '2011m', 'Schuljahr.4': '2011w', 'Schuljahr.5': '2011g',
                                'Schuljahr.6': '2012m', 'Schuljahr.7': '2012w', 'Schuljahr.8': '2012g',
                                'Schuljahr.9': '2013m', 'Schuljahr.10': '2013w', 'Schuljahr.11': '2013g',
                                'Schuljahr.12': '2014m', 'Schuljahr.13': '2014w', 'Schuljahr.14': '2014g',
                                'Schuljahr.15': '2015m', 'Schuljahr.16': '2015w', 'Schuljahr.17': '2015g',
                                'Schuljahr.18': '2016m', 'Schuljahr.19': '2016w', 'Schuljahr.20': '2016g',
                                'Schuljahr.21': '2017m', 'Schuljahr.22': '2017w', 'Schuljahr.23': '2017g',
                                'Schuljahr.24': '2018m', 'Schuljahr.25': '2018w', 'Schuljahr.26': '2018g',
                                'Schuljahr.27': '2019m', 'Schuljahr.28': '2019w', 'Schuljahr.29': '2019g',
                                'Schuljahr.30': '2020m', 'Schuljahr.31': '2020w', 'Schuljahr.32': '2020g',
                                'Schuljahr.33': '2021m', 'Schuljahr.34': '2021w', 'Schuljahr.35': '2021g'})
# Out:
#     Bundesland                                  Schule  \
# 135  Thüringen                            Hauptschulen
# 136  Thüringen  Schularten mit mehreren Bildungsgängen
# 137  Thüringen                             Realschulen
# 138  Thüringen                          Gymnasien (G9)
# 139  Thüringen                          Gymnasien (G8)
# 140  Thüringen               Integrierte Gesamtschulen
# 141  Thüringen                    Freie Waldorfschulen
# 142  Thüringen                           Förderschulen
# 143  Thüringen                               Insgesamt
#
#                     Abschluss 2010m 2010w 2010g 2011m 2011w 2011g 2012m  ...  \
# 135  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 136  Ohne Hauptschulabschluss   273   208   481   254   158   412   292  ...
# 137  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# 138  Ohne Hauptschulabschluss     -     -     -     -     -     -     -  ...
# ...

# %% [markdown]
# # Einteilung in Jahre pro Bundesland

# %% [markdown]
# ### Baden-Wüttemberg

# %%
dropouts_bw_2011 =dropouts_bw.iloc[:, [0,1,2,6,7,8]]
dropouts_bw_2012 =dropouts_bw.iloc[:, [0,1,2,9,10,11]]
dropouts_bw_2013 =dropouts_bw.iloc[:, [0,1,2,12,13,14]]
dropouts_bw_2014 =dropouts_bw.iloc[:, [0,1,2,15,16,17]]
dropouts_bw_2015 =dropouts_bw.iloc[:, [0,1,2,18,19,20]]
dropouts_bw_2016 =dropouts_bw.iloc[:, [0,1,2,21,22,23]]
dropouts_bw_2017 =dropouts_bw.iloc[:, [0,1,2,24,25,26]]
dropouts_bw_2018 =dropouts_bw.iloc[:, [0,1,2,27,28,29]]
dropouts_bw_2019 =dropouts_bw.iloc[:, [0,1,2,30,31,32]]
dropouts_bw_2020 =dropouts_bw.iloc[:, [0,1,2,33,34,35]]
dropouts_bw_2021 =dropouts_bw.iloc[:, [0,1,2,36,37,38]]

# %%
# Speichern in einer Excel datei
with pd.ExcelWriter('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/jw/bw_jahre.xlsx') as writer:
    dropouts_bw_2011.to_excel(writer, sheet_name='2011')
    dropouts_bw_2012.to_excel(writer, sheet_name='2012')
    dropouts_bw_2013.to_excel(writer, sheet_name='2013')
    dropouts_bw_2014.to_excel(writer, sheet_name='2014')
    dropouts_bw_2015.to_excel(writer, sheet_name='2015')
    dropouts_bw_2016.to_excel(writer, sheet_name='2016')
    dropouts_bw_2017.to_excel(writer, sheet_name='2017')
    dropouts_bw_2018.to_excel(writer, sheet_name='2018')
    dropouts_bw_2019.to_excel(writer, sheet_name='2019')
    dropouts_bw_2020.to_excel(writer, sheet_name='2020')
    dropouts_bw_2021.to_excel(writer, sheet_name='2021')

# %%
dropouts_bw_2011
# Out:
#           Unnamed: 0                              Unnamed: 1  \
# 0  Baden-Württemberg                            Hauptschulen
# 1  Baden-Württemberg  Schularten mit mehreren Bildungsgängen
# 2  Baden-Württemberg                             Realschulen
# 3  Baden-Württemberg                          Gymnasien (G9)
# 4  Baden-Württemberg                          Gymnasien (G8)
# 5  Baden-Württemberg               Integrierte Gesamtschulen
# 6  Baden-Württemberg                    Freie Waldorfschulen
# 7  Baden-Württemberg                           Förderschulen
# 8  Baden-Württemberg                               Insgesamt
#
#                   Abschluss Schuljahr.3 Schuljahr.4 Schuljahr.5
# 0  Ohne Hauptschulabschluss         679         443        1122
# 1  Ohne Hauptschulabschluss           -           -           -
# 2  Ohne Hauptschulabschluss         457         320         777
# 3  Ohne Hauptschulabschluss           -           -           -
# ...

# %%
import pandas as pd

# Beispiel DataFrame
df = pd.DataFrame({'Unnamed: 0': ['Baden-Württemberg', 'Baden-Württemberg', 'Baden-Württemberg', 'Baden-Württemberg', 'Baden-Württemberg', 'Baden-Württemberg', 'Baden-Württemberg', 'Baden-Württemberg', 'Baden-Württemberg'],
                   'Unnamed: 1': ['Hauptschulen', 'Schularten mit mehreren Bildungsgängen', 'Realschulen', 'Gymnasien (G9)', 'Gymnasien (G8)', 'Integrierte Gesamtschulen', 'Freie Waldorfschulen', 'Förderschulen', 'Insgesamt'],
                   'Abschluss': ['Ohne Hauptschulabschluss', 'Ohne Hauptschulabschluss', 'Ohne Hauptschulabschluss', 'Ohne Hauptschulabschluss', 'Ohne Hauptschulabschluss', 'Ohne Hauptschulabschluss', 'Ohne Hauptschulabschluss', 'Ohne Hauptschulabschluss', 'Ohne Hauptschulabschluss'],
                   'Schuljahr.3': [679, 0, 457, 0, 79, 1, 22, 2294, 3532],
                   'Schuljahr.4': [443, 0, 320, 0, 82, 1, 21, 1523, 2390],
                   'Schuljahr.5': [1122, 0, 777, 0, 161, 2, 43, 3817, 5922]})

# Berechnung der Prozentwerte
df['weiblich %'] = df['Schuljahr.4'] / df['Schuljahr.5'] * 100
df['männlich %'] = df['Schuljahr.3'] / df['Schuljahr.5'] * 100

# Ausgabe des aktualisierten DataFrames
df
# Out:
#           Unnamed: 0                              Unnamed: 1  \
# 0  Baden-Württemberg                            Hauptschulen
# 1  Baden-Württemberg  Schularten mit mehreren Bildungsgängen
# 2  Baden-Württemberg                             Realschulen
# 3  Baden-Württemberg                          Gymnasien (G9)
# 4  Baden-Württemberg                          Gymnasien (G8)
# 5  Baden-Württemberg               Integrierte Gesamtschulen
# 6  Baden-Württemberg                    Freie Waldorfschulen
# 7  Baden-Württemberg                           Förderschulen
# 8  Baden-Württemberg                               Insgesamt
#
#                   Abschluss  Schuljahr.3  Schuljahr.4  Schuljahr.5  \
# 0  Ohne Hauptschulabschluss          679          443         1122
# 1  Ohne Hauptschulabschluss            0            0            0
# 2  Ohne Hauptschulabschluss          457          320          777
# 3  Ohne Hauptschulabschluss            0            0            0
# ...

# %% [markdown]
# ### Bayern

# %%
dropouts_by_2011 =dropouts_by.iloc[:, [0,1,2,6,7,8]]
dropouts_by_2012 =dropouts_by.iloc[:, [0,1,2,9,10,11]]
dropouts_by_2013 =dropouts_by.iloc[:, [0,1,2,12,13,14]]
dropouts_by_2014 =dropouts_by.iloc[:, [0,1,2,15,16,17]]
dropouts_by_2015 =dropouts_by.iloc[:, [0,1,2,18,19,20]]
dropouts_by_2016 =dropouts_by.iloc[:, [0,1,2,21,22,23]]
dropouts_by_2017 =dropouts_by.iloc[:, [0,1,2,24,25,26]]
dropouts_by_2018 =dropouts_by.iloc[:, [0,1,2,27,28,29]]
dropouts_by_2019 =dropouts_by.iloc[:, [0,1,2,30,31,32]]
dropouts_by_2020 =dropouts_by.iloc[:, [0,1,2,33,34,35]]
dropouts_by_2021 =dropouts_by.iloc[:, [0,1,2,36,37,38]]

# %%
# Speichern in einer Excel datei
with pd.ExcelWriter('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/jw/by_jahre.xlsx') as writer:
    dropouts_by_2011.to_excel(writer, sheet_name='2011')
    dropouts_by_2012.to_excel(writer, sheet_name='2012')
    dropouts_by_2013.to_excel(writer, sheet_name='2013')
    dropouts_by_2014.to_excel(writer, sheet_name='2014')
    dropouts_by_2015.to_excel(writer, sheet_name='2015')
    dropouts_by_2016.to_excel(writer, sheet_name='2016')
    dropouts_by_2017.to_excel(writer, sheet_name='2017')
    dropouts_by_2018.to_excel(writer, sheet_name='2018')
    dropouts_by_2019.to_excel(writer, sheet_name='2019')
    dropouts_by_2020.to_excel(writer, sheet_name='2020')
    dropouts_by_2021.to_excel(writer, sheet_name='2021')

# %% [markdown]
# ### Berlin

# %%
dropouts_be_2011 =dropouts_be.iloc[:, [0,1,2,6,7,8]]
dropouts_be_2012 =dropouts_be.iloc[:, [0,1,2,9,10,11]]
dropouts_be_2013 =dropouts_be.iloc[:, [0,1,2,12,13,14]]
dropouts_be_2014 =dropouts_be.iloc[:, [0,1,2,15,16,17]]
dropouts_be_2015 =dropouts_be.iloc[:, [0,1,2,18,19,20]]
dropouts_be_2016 =dropouts_be.iloc[:, [0,1,2,21,22,23]]
dropouts_be_2017 =dropouts_be.iloc[:, [0,1,2,24,25,26]]
dropouts_be_2018 =dropouts_be.iloc[:, [0,1,2,27,28,29]]
dropouts_be_2019 =dropouts_be.iloc[:, [0,1,2,30,31,32]]
dropouts_be_2020 =dropouts_be.iloc[:, [0,1,2,33,34,35]]
dropouts_be_2021 =dropouts_be.iloc[:, [0,1,2,36,37,38]]

# %%
# Speichern in einer Excel datei
with pd.ExcelWriter('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/jw/be_jahre.xlsx') as writer:
    dropouts_be_2011.to_excel(writer, sheet_name='2011')
    dropouts_be_2012.to_excel(writer, sheet_name='2012')
    dropouts_be_2013.to_excel(writer, sheet_name='2013')
    dropouts_be_2014.to_excel(writer, sheet_name='2014')
    dropouts_be_2015.to_excel(writer, sheet_name='2015')
    dropouts_be_2016.to_excel(writer, sheet_name='2016')
    dropouts_be_2017.to_excel(writer, sheet_name='2017')
    dropouts_be_2018.to_excel(writer, sheet_name='2018')
    dropouts_be_2019.to_excel(writer, sheet_name='2019')
    dropouts_be_2020.to_excel(writer, sheet_name='2020')
    dropouts_be_2021.to_excel(writer, sheet_name='2021')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 3
#       2 with pd.ExcelWriter('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/jw/be_jahre.xlsx') as writer:
# ----> 3     dropouts_be_2011.to_excel(writer, sheet_name='2011')
#       4     dropouts_be_2012.to_excel(writer, sheet_name='2012')
#
# NameError: name 'dropouts_be_2011' is not defined
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[62], line 13
#      11 dropouts_be_2019.to_excel(writer, sheet_name='2019')
#      12 dropouts_be_2020.to_excel(writer, sheet_name='2020')
# ---> 13 dropouts_be_2021.to_excel(writer, sheet_name='2021')
#
# ...

# %% [markdown]
# ### Brandenburg

# %%
dropouts_bb_2011 =dropouts_bb.iloc[:, [0,1,2,6,7,8]]
dropouts_bb_2012 =dropouts_bb.iloc[:, [0,1,2,9,10,11]]
dropouts_bb_2013 =dropouts_bb.iloc[:, [0,1,2,12,13,14]]
dropouts_bb_2014 =dropouts_bb.iloc[:, [0,1,2,15,16,17]]
dropouts_bb_2015 =dropouts_bb.iloc[:, [0,1,2,18,19,20]]
dropouts_bb_2016 =dropouts_bb.iloc[:, [0,1,2,21,22,23]]
dropouts_bb_2017 =dropouts_bb.iloc[:, [0,1,2,24,25,26]]
dropouts_bb_2018 =dropouts_bb.iloc[:, [0,1,2,27,28,29]]
dropouts_bb_2019 =dropouts_bb.iloc[:, [0,1,2,30,31,32]]
dropouts_bb_2020 =dropouts_bb.iloc[:, [0,1,2,33,34,35]]
dropouts_bb_2021 =dropouts_bb.iloc[:, [0,1,2,36,37,38]]

# %%
# Speichern in einer Excel datei
with pd.ExcelWriter('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/jw/brandenburg_jahre.xlsx') as writer:
    dropouts_bb_2011.to_excel(writer, sheet_name='2011')
    dropouts_bb_2012.to_excel(writer, sheet_name='2012')
    dropouts_bb_2013.to_excel(writer, sheet_name='2013')
    dropouts_bb_2014.to_excel(writer, sheet_name='2014')
    dropouts_bb_2015.to_excel(writer, sheet_name='2015')
    dropouts_bb_2016.to_excel(writer, sheet_name='2016')
    dropouts_bb_2017.to_excel(writer, sheet_name='2017')
    dropouts_bb_2018.to_excel(writer, sheet_name='2018')
    dropouts_bb_2019.to_excel(writer, sheet_name='2019')
    dropouts_bb_2020.to_excel(writer, sheet_name='2020')
    dropouts_bb_2021.to_excel(writer, sheet_name='2021')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 3
#       2 with pd.ExcelWriter('/Users/jw/Documents/Neue_Fische_Bootcamp/capstone_project_hh_23_1/data/jw/brandenburg_jahre.xlsx') as writer:
# ----> 3     dropouts_bb_2011.to_excel(writer, sheet_name='2011')
#       4     dropouts_bb_2012.to_excel(writer, sheet_name='2012')
#
# NameError: name 'dropouts_bb_2011' is not defined
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 13
#      11 dropouts_bb_2019.to_excel(writer, sheet_name='2019')
#      12 dropouts_bb_2020.to_excel(writer, sheet_name='2020')
# ---> 13 dropouts_bb_2021.to_excel(writer, sheet_name='2021')
#
# ...

# %% [markdown]
# ### Bremen

# %%
dropouts_hb_2011 =dropouts_hb.iloc[:, [0,1,2,6,7,8]]
dropouts_hb_2012 =dropouts_hb.iloc[:, [0,1,2,9,10,11]]
dropouts_hb_2013 =dropouts_hb.iloc[:, [0,1,2,12,13,14]]
dropouts_hb_2014 =dropouts_hb.iloc[:, [0,1,2,15,16,17]]
dropouts_hb_2015 =dropouts_hb.iloc[:, [0,1,2,18,19,20]]
dropouts_hb_2016 =dropouts_hb.iloc[:, [0,1,2,21,22,23]]
dropouts_hb_2017 =dropouts_hb.iloc[:, [0,1,2,24,25,26]]
dropouts_hb_2018 =dropouts_hb.iloc[:, [0,1,2,27,28,29]]
dropouts_hb_2019 =dropouts_hb.iloc[:, [0,1,2,30,31,32]]
dropouts_hb_2020 =dropouts_hb.iloc[:, [0,1,2,33,34,35]]
dropouts_hb_2021 =dropouts_hb.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Hamburg

# %%
dropouts_hh_2011 =dropouts_hh.iloc[:, [0,1,2,6,7,8]]
dropouts_hh_2012 =dropouts_hh.iloc[:, [0,1,2,9,10,11]]
dropouts_hh_2013 =dropouts_hh.iloc[:, [0,1,2,12,13,14]]
dropouts_hh_2014 =dropouts_hh.iloc[:, [0,1,2,15,16,17]]
dropouts_hh_2015 =dropouts_hh.iloc[:, [0,1,2,18,19,20]]
dropouts_hh_2016 =dropouts_hh.iloc[:, [0,1,2,21,22,23]]
dropouts_hh_2017 =dropouts_hh.iloc[:, [0,1,2,24,25,26]]
dropouts_hh_2018 =dropouts_hh.iloc[:, [0,1,2,27,28,29]]
dropouts_hh_2019 =dropouts_hh.iloc[:, [0,1,2,30,31,32]]
dropouts_hh_2020 =dropouts_hh.iloc[:, [0,1,2,33,34,35]]
dropouts_hh_2021 =dropouts_hh.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Hessen

# %%
dropouts_he_2011 =dropouts_he.iloc[:, [0,1,2,6,7,8]]
dropouts_he_2012 =dropouts_he.iloc[:, [0,1,2,9,10,11]]
dropouts_he_2013 =dropouts_he.iloc[:, [0,1,2,12,13,14]]
dropouts_he_2014 =dropouts_he.iloc[:, [0,1,2,15,16,17]]
dropouts_he_2015 =dropouts_he.iloc[:, [0,1,2,18,19,20]]
dropouts_he_2016 =dropouts_he.iloc[:, [0,1,2,21,22,23]]
dropouts_he_2017 =dropouts_he.iloc[:, [0,1,2,24,25,26]]
dropouts_he_2018 =dropouts_he.iloc[:, [0,1,2,27,28,29]]
dropouts_he_2019 =dropouts_he.iloc[:, [0,1,2,30,31,32]]
dropouts_he_2020 =dropouts_he.iloc[:, [0,1,2,33,34,35]]
dropouts_he_2021 =dropouts_he.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Mecklenburg-Vorpommern

# %%
dropouts_mv_2011 =dropouts_mv.iloc[:, [0,1,2,6,7,8]]
dropouts_mv_2012 =dropouts_mv.iloc[:, [0,1,2,9,10,11]]
dropouts_mv_2013 =dropouts_mv.iloc[:, [0,1,2,12,13,14]]
dropouts_mv_2014 =dropouts_mv.iloc[:, [0,1,2,15,16,17]]
dropouts_mv_2015 =dropouts_mv.iloc[:, [0,1,2,18,19,20]]
dropouts_mv_2016 =dropouts_mv.iloc[:, [0,1,2,21,22,23]]
dropouts_mv_2017 =dropouts_mv.iloc[:, [0,1,2,24,25,26]]
dropouts_mv_2018 =dropouts_mv.iloc[:, [0,1,2,27,28,29]]
dropouts_mv_2019 =dropouts_mv.iloc[:, [0,1,2,30,31,32]]
dropouts_mv_2020 =dropouts_mv.iloc[:, [0,1,2,33,34,35]]
dropouts_mv_2021 =dropouts_mv.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Niedersachsen

# %%
dropouts_ni_2011 =dropouts_ni.iloc[:, [0,1,2,6,7,8]]
dropouts_ni_2012 =dropouts_ni.iloc[:, [0,1,2,9,10,11]]
dropouts_ni_2013 =dropouts_ni.iloc[:, [0,1,2,12,13,14]]
dropouts_ni_2014 =dropouts_ni.iloc[:, [0,1,2,15,16,17]]
dropouts_ni_2015 =dropouts_ni.iloc[:, [0,1,2,18,19,20]]
dropouts_ni_2016 =dropouts_ni.iloc[:, [0,1,2,21,22,23]]
dropouts_ni_2017 =dropouts_ni.iloc[:, [0,1,2,24,25,26]]
dropouts_ni_2018 =dropouts_ni.iloc[:, [0,1,2,27,28,29]]
dropouts_ni_2019 =dropouts_ni.iloc[:, [0,1,2,30,31,32]]
dropouts_ni_2020 =dropouts_ni.iloc[:, [0,1,2,33,34,35]]
dropouts_ni_2021 =dropouts_ni.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Nordrhein-Westphalen

# %%
dropouts_nrw_2011 =dropouts_nrw.iloc[:, [0,1,2,6,7,8]]
dropouts_nrw_2012 =dropouts_nrw.iloc[:, [0,1,2,9,10,11]]
dropouts_nrw_2013 =dropouts_nrw.iloc[:, [0,1,2,12,13,14]]
dropouts_nrw_2014 =dropouts_nrw.iloc[:, [0,1,2,15,16,17]]
dropouts_nrw_2015 =dropouts_nrw.iloc[:, [0,1,2,18,19,20]]
dropouts_nrw_2016 =dropouts_nrw.iloc[:, [0,1,2,21,22,23]]
dropouts_nrw_2017 =dropouts_nrw.iloc[:, [0,1,2,24,25,26]]
dropouts_nrw_2018 =dropouts_nrw.iloc[:, [0,1,2,27,28,29]]
dropouts_nrw_2019 =dropouts_nrw.iloc[:, [0,1,2,30,31,32]]
dropouts_nrw_2020 =dropouts_nrw.iloc[:, [0,1,2,33,34,35]]
dropouts_nrw_2021 =dropouts_nrw.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Rheinland-Pfalz

# %%
dropouts_rp_2011 =dropouts_rp.iloc[:, [0,1,2,6,7,8]]
dropouts_rp_2012 =dropouts_rp.iloc[:, [0,1,2,9,10,11]]
dropouts_rp_2013 =dropouts_rp.iloc[:, [0,1,2,12,13,14]]
dropouts_rp_2014 =dropouts_rp.iloc[:, [0,1,2,15,16,17]]
dropouts_rp_2015 =dropouts_rp.iloc[:, [0,1,2,18,19,20]]
dropouts_rp_2016 =dropouts_rp.iloc[:, [0,1,2,21,22,23]]
dropouts_rp_2017 =dropouts_rp.iloc[:, [0,1,2,24,25,26]]
dropouts_rp_2018 =dropouts_rp.iloc[:, [0,1,2,27,28,29]]
dropouts_rp_2019 =dropouts_rp.iloc[:, [0,1,2,30,31,32]]
dropouts_rp_2020 =dropouts_rp.iloc[:, [0,1,2,33,34,35]]
dropouts_rp_2021 =dropouts_rp.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Saarland

# %%
dropouts_saar_2011 =dropouts_saar.iloc[:, [0,1,2,6,7,8]]
dropouts_saar_2012 =dropouts_saar.iloc[:, [0,1,2,9,10,11]]
dropouts_saar_2013 =dropouts_saar.iloc[:, [0,1,2,12,13,14]]
dropouts_saar_2014 =dropouts_saar.iloc[:, [0,1,2,15,16,17]]
dropouts_saar_2015 =dropouts_saar.iloc[:, [0,1,2,18,19,20]]
dropouts_saar_2016 =dropouts_saar.iloc[:, [0,1,2,21,22,23]]
dropouts_saar_2017 =dropouts_saar.iloc[:, [0,1,2,24,25,26]]
dropouts_saar_2018 =dropouts_saar.iloc[:, [0,1,2,27,28,29]]
dropouts_saar_2019 =dropouts_saar.iloc[:, [0,1,2,30,31,32]]
dropouts_saar_2020 =dropouts_saar.iloc[:, [0,1,2,33,34,35]]
dropouts_saar_2021 =dropouts_saar.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Sachsen

# %%
dropouts_sachsen_2011 =dropouts_sachsen.iloc[:, [0,1,2,6,7,8]]
dropouts_sachsen_2012 =dropouts_sachsen.iloc[:, [0,1,2,9,10,11]]
dropouts_sachsen_2013 =dropouts_sachsen.iloc[:, [0,1,2,12,13,14]]
dropouts_sachsen_2014 =dropouts_sachsen.iloc[:, [0,1,2,15,16,17]]
dropouts_sachsen_2015 =dropouts_sachsen.iloc[:, [0,1,2,18,19,20]]
dropouts_sachsen_2016 =dropouts_sachsen.iloc[:, [0,1,2,21,22,23]]
dropouts_sachsen_2017 =dropouts_sachsen.iloc[:, [0,1,2,24,25,26]]
dropouts_sachsen_2018 =dropouts_sachsen.iloc[:, [0,1,2,27,28,29]]
dropouts_sachsen_2019 =dropouts_sachsen.iloc[:, [0,1,2,30,31,32]]
dropouts_sachsen_2020 =dropouts_sachsen.iloc[:, [0,1,2,33,34,35]]
dropouts_sachsen_2021 =dropouts_sachsen.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Sachsen-Anhalt

# %%
dropouts_sa_anh_2011 =dropouts_sa_anh.iloc[:, [0,1,2,6,7,8]]
dropouts_sa_anh_2012 =dropouts_sa_anh.iloc[:, [0,1,2,9,10,11]]
dropouts_sa_anh_2013 =dropouts_sa_anh.iloc[:, [0,1,2,12,13,14]]
dropouts_sa_anh_2014 =dropouts_sa_anh.iloc[:, [0,1,2,15,16,17]]
dropouts_sa_anh_2015 =dropouts_sa_anh.iloc[:, [0,1,2,18,19,20]]
dropouts_sa_anh_2016 =dropouts_sa_anh.iloc[:, [0,1,2,21,22,23]]
dropouts_sa_anh_2017 =dropouts_sa_anh.iloc[:, [0,1,2,24,25,26]]
dropouts_sa_anh_2018 =dropouts_sa_anh.iloc[:, [0,1,2,27,28,29]]
dropouts_sa_anh_2019 =dropouts_sa_anh.iloc[:, [0,1,2,30,31,32]]
dropouts_sa_anh_2020 =dropouts_sa_anh.iloc[:, [0,1,2,33,34,35]]
dropouts_sa_anh_2021 =dropouts_sa_anh.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Schleswig-Holstein

# %%
dropouts_sh_2011 =dropouts_sh.iloc[:, [0,1,2,6,7,8]]
dropouts_sh_2012 =dropouts_sh.iloc[:, [0,1,2,9,10,11]]
dropouts_sh_2013 =dropouts_sh.iloc[:, [0,1,2,12,13,14]]
dropouts_sh_2014 =dropouts_sh.iloc[:, [0,1,2,15,16,17]]
dropouts_sh_2015 =dropouts_sh.iloc[:, [0,1,2,18,19,20]]
dropouts_sh_2016 =dropouts_sh.iloc[:, [0,1,2,21,22,23]]
dropouts_sh_2017 =dropouts_sh.iloc[:, [0,1,2,24,25,26]]
dropouts_sh_2018 =dropouts_sh.iloc[:, [0,1,2,27,28,29]]
dropouts_sh_2019 =dropouts_sh.iloc[:, [0,1,2,30,31,32]]
dropouts_sh_2020 =dropouts_sh.iloc[:, [0,1,2,33,34,35]]
dropouts_sh_2021 =dropouts_sh.iloc[:, [0,1,2,36,37,38]]

# %% [markdown]
# ### Thüringen

# %%
dropouts_th_2011 =dropouts_th.iloc[:, [0,1,2,6,7,8]]
dropouts_th_2012 =dropouts_th.iloc[:, [0,1,2,9,10,11]]
dropouts_th_2013 =dropouts_th.iloc[:, [0,1,2,12,13,14]]
dropouts_th_2014 =dropouts_th.iloc[:, [0,1,2,15,16,17]]
dropouts_th_2015 =dropouts_th.iloc[:, [0,1,2,18,19,20]]
dropouts_th_2016 =dropouts_th.iloc[:, [0,1,2,21,22,23]]
dropouts_th_2017 =dropouts_th.iloc[:, [0,1,2,24,25,26]]
dropouts_th_2018 =dropouts_th.iloc[:, [0,1,2,27,28,29]]
dropouts_th_2019 =dropouts_th.iloc[:, [0,1,2,30,31,32]]
dropouts_th_2020 =dropouts_th.iloc[:, [0,1,2,33,34,35]]
dropouts_th_2021 =dropouts_th.iloc[:, [0,1,2,36,37,38]]
