# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')


#input custom functions
from avg_noten_data import avg_noten_2010, avg_noten_2011, avg_noten_2012, avg_noten_2013, avg_noten_2014, avg_noten_2015, avg_noten_2016, avg_noten_2017, avg_noten_2018, avg_noten_2019, avg_noten_2020, avg_noten_2021, avg_noten_2022
avg_noten_concat = pd.concat([avg_noten_2010, avg_noten_2011, avg_noten_2012,
                          avg_noten_2013, avg_noten_2014, avg_noten_2015,
                          avg_noten_2016, avg_noten_2017, avg_noten_2018,
                          avg_noten_2019, avg_noten_2020, avg_noten_2021,
                          avg_noten_2022
                          ], ignore_index=True)
# Out:
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/avg_noten_data.py:58: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   noten_data.iloc[:, 1:17] = noten_data.iloc[:, 1:17].astype(float)
# /Users/kamilkarim/neuefische/capstone_project_hh_23_1/avg_noten_data.py:58: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   noten_data.iloc[:, 1:17] = noten_data.iloc[:, 1:17].astype(float)
# ...

# %%
# Define a dictionary to map old column names to new column names
column_mapping = {'TH': 'Thüringen', 'BW': 'Baden-Wüttemberg', 'BY': 'Bayern', 'BE': 'Berlin',
                      'BB': 'Brandenburg', 'HB': 'Bremen', 'HH': 'Hamburg', 'HE': 'Hessen', 'MV': 'Mecklenburg-Vorpommern',
                      'NI': 'Niedersachsen', 'NW': 'Nordrhein-Westfalen', 'RP': 'Rheinland-Pfalz',
                      'SL': 'Saarland', 'SN': 'Sachsen', 'ST': 'Sachsen-Anhalt', 'SH': 'Schleswig-Holstein'}

# Use the rename() method to rename the columns
avg_noten_concat.rename(columns=column_mapping, inplace=True)

# %%
avg_noten_concat
# Out:
#       Baden-Wüttemberg  Bayern  Berlin  Brandenburg  Bremen  Hamburg  Hessen  \
# 0                 2.44    2.40    2.48         2.40    2.45     2.49    2.44
# 1                 2.44    2.37    2.45         2.38    2.47     2.49    2.43
# 2                 2.41    2.35    2.40         2.33    2.45     2.46    2.43
# 3                 2.46    2.35    2.44         2.38    2.47     2.45    2.42
# 4                 2.46    2.33    2.42         2.31    2.46     2.43    2.43
# 5                 2.44    2.31    2.39         2.30    2.45     2.43    2.43
# 6                 2.43    2.32    2.39         2.28    2.44     2.44    2.40
# 7                 2.42    2.31    2.41         2.27    2.47     2.43    2.41
# 8                 2.44    2.31    2.42         2.29    2.41     2.41    2.39
# 9                 2.41    2.32    2.42         2.27    2.40     2.42    2.37
# 10                2.38    2.29    2.35         2.28    2.40     2.36    2.33
# ...

# %%
#avg_noten_concat.to_csv('./Tableau/avg_noten_concat_kk.csv', index=False)

# %%
avg_noten_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0           13 non-null     object
#  1   BW      13 non-null     float64
#  2   BY      13 non-null     float64
#  3   BE      13 non-null     float64
#  4   BB      13 non-null     float64
#  5   HB      13 non-null     float64
#  6   HH      13 non-null     float64
#  7   HE      13 non-null     float64
#  8   MV      13 non-null     float64
#  9   NI      13 non-null     float64
#  10  NW      13 non-null     float64
#  11  RP      13 non-null     float64
#  12  SL      13 non-null     float64
#  13  SN      13 non-null     float64
#  14  ST      13 non-null     float64
#  15  SH      13 non-null     float64
#  16  TH      13 non-null     float64
#  17  year    13 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(16), object(1)
# memory usage: 2.0+ KB

# %% [markdown]
# Short explanation of the describe measures:
# - count: Indication of how many values are present in the columns (NaNs/missing values are not counted).
# - mean: average value of the data
# - std: standard deviation of the data
# - min: the smallest value in the data set
# - 25%: 25 % of the data are below this value
# - 50%: 50% of the data are below this value. This value is called the median.
# - 75%: 75% of the data are below this value
# - max: the largest expression in the data set

# %%
avg_noten_concat.describe()
# Out:
#        Baden-Wüttemberg     Bayern     Berlin  Brandenburg     Bremen  \
# count         13.000000  13.000000  13.000000    13.000000  13.000000
# mean           2.399231   2.310769   2.386923     2.293077   2.423846
# std            0.078152   0.061164   0.076527     0.073755   0.052367
# min            2.230000   2.180000   2.220000     2.150000   2.320000
# 25%            2.410000   2.310000   2.390000     2.270000   2.400000
# 50%            2.430000   2.320000   2.410000     2.290000   2.450000
# 75%            2.440000   2.350000   2.420000     2.330000   2.460000
# max            2.460000   2.400000   2.480000     2.400000   2.470000
#
#          Hamburg     Hessen  Mecklenburg-Vorpommern  Niedersachsen  \
# count  13.000000  13.000000               13.000000      13.000000
# mean    2.412308   2.381538                2.341538       2.567692
# std     0.069541   0.069863                0.071396       0.089084
# ...

# %%
# Filter data until 2019
avg_noten_until_2019 = avg_noten_concat[avg_noten_concat['year'] <= '2019-01-01']

# Set up plot style
sns.set_style("darkgrid")

# Create line plot for each federal state
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_noten_until_2019, x='year', y='ST', label='ST')
sns.lineplot(data=avg_noten_until_2019, x='year', y='SH', label='SH')
sns.lineplot(data=avg_noten_until_2019, x='year', y='TH', label='TH')
plt.xlabel('Year')
plt.ylabel('Average Grade')
plt.title('Average Grades by Federal State (Until 2019)')
plt.legend()
plt.show()

# %%
# Filter data from 2020 to 2022
avg_noten_2020_to_2022 = avg_noten_concat[(avg_noten_concat['year'] >= '2020-01-01') & (avg_noten_concat['year'] <= '2022-01-01')]

# Set up plot style
sns.set_style("darkgrid")

# Create line plot for each federal state
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_noten_2020_to_2022, x='year', y='ST', label='ST')
sns.lineplot(data=avg_noten_2020_to_2022, x='year', y='SH', label='SH')
sns.lineplot(data=avg_noten_2020_to_2022, x='year', y='TH', label='TH')
plt.xlabel('Year')
plt.ylabel('Average Grade')
plt.title('Average Grades by Federal State (2020-2022)')
plt.legend()
plt.show()

# %%
# Separate data into grades until 2019 and from 2020 to 2022
grades_until_2019 = avg_noten_concat[avg_noten_concat['year'].dt.year <= 2019]
grades_from_2020_to_2022 = avg_noten_concat[avg_noten_concat['year'].dt.year >= 2020]

# Plot line charts for each federal state
plt.figure(figsize=(12, 6))
for col in grades_until_2019.columns[:-1]:
    plt.plot(grades_until_2019['year'], grades_until_2019[col], label=col)
for col in grades_from_2020_to_2022.columns[:-1]:
    plt.plot(grades_from_2020_to_2022['year'], grades_from_2020_to_2022[col], label=col)
plt.xlabel('Year')
plt.ylabel('Average Grade')
plt.title('Grades Until 2019 and From 2020 to 2022')
plt.legend()
plt.show()

# %%
# Define the list of federal states in Germany
federal_states = ['Baden-Württemberg', 'Bavaria', 'Berlin', 'Brandenburg', 'Bremen', 'Hamburg', 'Hesse',
                  'Lower Saxony', 'Mecklenburg-Vorpommern', 'North Rhine-Westphalia', 'Rhineland-Palatinate',
                  'Saarland', 'Saxony', 'Saxony-Anhalt', 'Schleswig-Holstein', 'Thuringia']

# %%
import matplotlib.pyplot as plt

# Extract the relevant data for grades until 2019
grades_until_2019 = avg_noten_concat[avg_noten_concat['year'] <= '2019-01-01']

# Calculate the average grade for each federal state until 2019
avg_grades_until_2019 = grades_until_2019.groupby('year').mean()

# Extract the relevant data for grades from 2020 till 2022
grades_from_2020_to_2022 = avg_noten_concat[avg_noten_concat['year'] >= '2020-01-01']

# Calculate the average grade for each federal state from 2020 till 2022
avg_grades_from_2020_to_2022 = grades_from_2020_to_2022.groupby('year').mean()

# Plot the average grades until 2019
plt.figure(figsize=(10, 6))
for state in federal_states:
    plt.plot(avg_grades_until_2019.index, avg_grades_until_2019[state], label=state)
plt.title('Average Grades Until 2019')
plt.xlabel('Year')
plt.ylabel('Average Grade')
plt.legend(loc='best')
plt.show()

# Plot the average grades from 2020 till 2022
plt.figure(figsize=(10, 6))
for state in federal_states:
    plt.plot(avg_grades_from_2020_to_2022.index, avg_grades_from_2020_to_2022[state], label=state)
plt.title('Average Grades From 2020 to 2022')
plt.xlabel('Year')
plt.ylabel('Average Grade')
plt.legend(loc='best')
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the list of federal states in Germany
federal_states = ['Baden-Württemberg', 'Bavaria', 'Berlin', 'Brandenburg', 'Bremen', 'Hamburg', 'Hesse',
                  'Lower Saxony', 'Mecklenburg-Vorpommern', 'North Rhine-Westphalia', 'Rhineland-Palatinate',
                  'Saarland', 'Saxony', 'Saxony-Anhalt', 'Schleswig-Holstein', 'Thuringia']

# Extract the relevant data for grades until 2019
grades_until_2019 = avg_noten_concat[avg_noten_concat['year'] <= '2019-01-01']

# Calculate the average grade for each federal state until 2019
avg_grades_until_2019 = grades_until_2019.groupby('year').mean()

# Extract the relevant data for grades from 2020 till 2022
grades_from_2020_to_2022 = avg_noten_concat[avg_noten_concat['year'] >= '2020-01-01']

# Calculate the average grade for each federal state from 2020 till 2022
avg_grades_from_2020_to_2022 = grades_from_2020_to_2022.groupby('year').mean()

# Plot the average grades until 2019
plt.figure(figsize=(10, 6))
for state in federal_states:
    plt.plot(avg_grades_until_2019.index, avg_grades_until_2019[state], label=state)
plt.title('Average Grades Until 2019')
plt.xlabel('Year')
plt.ylabel('Average Grade')
plt.legend(loc='best')
plt.show()

# Plot the average grades from 2020 till 2022
plt.figure(figsize=(10, 6))
for state in federal_states:
    plt.plot(avg_grades_from_2020_to_2022.index, avg_grades_from_2020_to_2022[state], label=state)
plt.title('Average Grades From 2020 to 2022')
plt.xlabel('Year')
plt.ylabel('Average Grade')
plt.legend(loc='best')
plt.show()

# %%
# Calculate the mean for each column
plt.figure(figsize=(15,8)) # specify figure size
mean_values = avg_noten_concat.mean()

# Find the column with the smallest mean
best_state = mean_values.idxmin()

# Create a bar chart for the smallest mean
mean_values.plot(kind='bar')
plt.xlabel('Federal State')
plt.ylabel('Mean Value')
plt.title(f'Bar Chart for Smallest Mean (Best Federal State: {best_state})')
plt.show()
# Out:
# /var/folders/lh/4nwxm20s6c50ws3gs23vtn6r0000gn/T/ipykernel_43510/1511275692.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mean_values = avg_noten_concat.mean()
# /var/folders/lh/4nwxm20s6c50ws3gs23vtn6r0000gn/T/ipykernel_43510/1511275692.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values = avg_noten_concat.mean()

# %%
avg_noten_concat

# %%
# Create a DataFrame from the dataset
#df = pd.DataFrame(data, index=index)

# Calculate the mean for each column
mean_values = avg_noten_concat.mean()

# Sort mean values in ascending order
mean_values = mean_values.sort_values(ascending=True)

# Find the column with the smallest mean
#best_state = mean_values.idxmin()

# Find the column with the smallest mean
#best_state = mean_values.idxmin()

# Set Seaborn style
#sns.set(style='darkgrid')

# Create a bar chart for the smallest mean using Seaborn
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=mean_values.index, y=mean_values.values)
plt.tick_params(axis='x', rotation=75)
plt.xlabel('Federal States')
plt.ylabel('Average Grades')
#plt.title(f'The best Federal State with average grade throughout the years is: {best_state}')
#plt.title(f'The best Federal State with average grade throughout the years is: {best_state}')

plt.ylim(bottom=2.1)  # Set the y-axis lower limit to 0

# Add value labels on top of each bar
for i, v in enumerate(mean_values.values):
    ax.text(i, v, str(round(v, 2)), ha='center', va='bottom')

plt.show()
# Out:
# /var/folders/lh/4nwxm20s6c50ws3gs23vtn6r0000gn/T/ipykernel_48567/1742922002.py:5: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   mean_values = avg_noten_concat.mean()
# /var/folders/lh/4nwxm20s6c50ws3gs23vtn6r0000gn/T/ipykernel_48567/1742922002.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values = avg_noten_concat.mean()

# %%
# Extract the row corresponding to the year 2010
row_2010 = avg_noten_concat.loc['2010-01-01']

# Find the column with the smallest value in the row
smallest_column_2010 = row_2010.idxmin()

print(f"The column with the smallest value in the year 2010 is: {smallest_column_2010}")

# %% [markdown]
# #### Federal state with the the best avg grade throughout the years

# %%
mean_grade_by_state = avg_noten_concat.groupby('Federal States')['AVG Grade'].mean()

# %%
state_with_smallest_avg_grade = mean_grade_by_state.idxmin()

# %%
print("The federal state with the smallest average grade throughout the years is:", state_with_smallest_avg_grade)
# Out:
# The federal state with the smallest average grade throughout the years is: TH

# %%
plt.figure(figsize=(15,8)) # specify figure size
f1 = sns.barplot(x=avg_noten_concat['year'], y=avg_noten_concat['AVG Grade']) # create countplot
f1.tick_params(axis=('both'), rotation=90) # get x-ticks and rotate them
f1.set(xlabel=None) # set no label for x-axis
f1.set(ylabel='Average Grade') # set no label for x-axis 
#f1.set_ylabel("Students that Graduated with 1 throughout the years", fontsize = 10); # set label for y-axis
f1.set_title('Average grades throughout the years', fontsize=18); # set title
plt.show()
